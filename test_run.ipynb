# %%
# %load_ext autoreload
# %autoreload 2

#from Mission_Planner import Mission_Planner
from Simulator import Sim_Start_Forward, Sim_Start_Hover_Climb
from Params import *

# %%
#Mission_Planner(fuel_weight=600, hover_endurance=40, climb_endurance=40, climb_velocity=10)

# %%
# Reload the helper_functions module so changes are picked up
import helper_functions
from importlib import reload
reload(helper_functions)

# Reload Simulator as well so it sees the updated helper_functions
import Simulator
from importlib import reload
reload(Simulator)

# Now import the function and run
from Simulator import Sim_Start_Forward,Sim_Start_Hover_Climb
from Params import *

result = Sim_Start_Hover_Climb(rotor, rotor_aero, engine, flight_condition)
print(result)

# %%
# Reload the helper_functions module so changes are picked up
import helper_functions
from importlib import reload
reload(helper_functions)

# Reload Simulator as well so it sees the updated helper_functions
import Simulator
from importlib import reload
reload(Simulator)

# Now import the function and run
from Simulator import Sim_Start_Forward,Sim_Start_Hover_Climb
from Params import *

result = Sim_Start_Forward(rotor, rotor_aero, engine, flight_condition)
print(result)
# Out:
# 0.015343650416978154
# 0.015343982048340738
# Converged B0 (coning angle): 0.015343982048340738
# Thrust: 74931.65800800567 Power: 3947251.167788352
# Scalar parameters:
# b = 4
# rho = 0.9927072111836429
# altitude = 2000
# R_tip = 8
# R_root = 1
# Omega = 27
# sigma = 0.08276057040778557
# a = 5.73
# V_inf = 100
# AR = 13.461538461538462
# TOGW = 6500
# alpha_tpp = 0.15459153644857665
# B_dot = 4.173971484111569
# B1c = 0.15459153644857665
# mu = 0.45744190138656
#
# Sample values at selected r and azimuth positions:
#  r (m)  theta (deg)  lambda  v_induced (m/s)  phi (deg)  chord (m)      Cl      Cd
#  1.000        0.000 0.00082           0.1771      0.936       0.52  0.2064 0.01126
#  1.000        1.928 0.00081           0.1742      0.320       0.52  0.4609 0.01628
#  1.000        2.954 0.00077           0.1669      0.163       0.52  0.5791 0.01991
#  1.000        2.598 0.00073           0.1586      0.200       0.52  0.5398 0.01861
# ...
